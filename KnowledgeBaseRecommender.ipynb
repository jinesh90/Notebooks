# %%
import pandas as pd

# %%
from ast import literal_eval

# %%
df_movie = pd.read_csv("/home/jinesh/Desktop/movies_metadata.csv")

# %%
df_movie.columns
# Out:
# Index([u'adult', u'belongs_to_collection', u'budget', u'genres', u'homepage',
#        u'id', u'imdb_id', u'original_language', u'original_title', u'overview',
#        u'popularity', u'poster_path', u'production_companies',
#        u'production_countries', u'release_date', u'revenue', u'runtime',
#        u'spoken_languages', u'status', u'tagline', u'title', u'video',
#        u'vote_average', u'vote_count'],
#       dtype='object')

# %%
#Only keep those features that we require

# %%
df_movie=df_movie[['title','genres', 'release_date', 'runtime', 'vote_average', 'vote_count']]

# %%
df_movie['release_date'] = df_movie['release_date'].fillna('0-0-0')

# %%
def get_release_year(x):
    return int(x.split('-')[0])

# %%
df_movie['release_year'] = df_movie['release_date'].apply(get_release_year)

# %%
df_movie
# Out:
#                                   title  \
# 0                             Toy Story
# 1                               Jumanji
# 2                      Grumpier Old Men
# 3                     Waiting to Exhale
# 4           Father of the Bride Part II
# 5                                  Heat
# 6                               Sabrina
# 7                          Tom and Huck
# 8                          Sudden Death
# 9                             GoldenEye
# 10               The American President
# 11          Dracula: Dead and Loving It
# 12                                Balto
# 13                                Nixon
# 14                     Cutthroat Island
# 15                               Casino
# 16                Sense and Sensibility
# 17                           Four Rooms
# 18       Ace Ventura: When Nature Calls
# 19                          Money Train
# 20                           Get Shorty
# 21                              Copycat
# ...

# %%
df_movie.drop('release_date',axis=1)
# Out:
#                                   title  \
# 0                             Toy Story
# 1                               Jumanji
# 2                      Grumpier Old Men
# 3                     Waiting to Exhale
# 4           Father of the Bride Part II
# 5                                  Heat
# 6                               Sabrina
# 7                          Tom and Huck
# 8                          Sudden Death
# 9                             GoldenEye
# 10               The American President
# 11          Dracula: Dead and Loving It
# 12                                Balto
# 13                                Nixon
# 14                     Cutthroat Island
# 15                               Casino
# 16                Sense and Sensibility
# 17                           Four Rooms
# 18       Ace Ventura: When Nature Calls
# 19                          Money Train
# 20                           Get Shorty
# 21                              Copycat
# ...

# %%
df_movie = df_movie.drop('release_date',axis=1)

# %%
df_movie.iloc[100]['genres']
# Out:
# "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]"

# %%
df_movie['genres'] = df_movie['genres'].fillna('[]')

# %%
df_movie['genres'] = df_movie['genres'].apply(literal_eval)

# %%
df_movie['genres'] = df_movie['genres'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df_movie['genres'] = df_movie['genres'].apply(lambda x: x[0] if x else [])

# %% [markdown]
# df_movie

# %%
g = "Drama"

# %%
low_year = 1930

# %%
high_year = 1950

# %%
movies = df_movie.copy()

# %%
movies = movies[(movies['release_year'] >= low_year) & (movies['release_year'] <= high_year) & (movies['genres'] == g )]

# %% [markdown]
# movies

# %%
movies
# Out:
#                                  title genres  runtime  vote_average  \
# 728                      Force of Evil  Drama     78.0           6.6
# 731            The Man from Down Under  Drama    103.0           0.0
# 867                           Liebelei  Drama     88.0           6.3
# 870            For Whom the Bell Tolls  Drama    170.0           6.1
# 879                           Gaslight  Drama    114.0           7.2
# 885                         Casablanca  Drama    102.0           7.9
# 890                The Little Princess  Drama     93.0           7.0
# 893                 Gone with the Wind  Drama    238.0           7.7
# 895                   Sunset Boulevard  Drama    110.0           8.2
# 899                      All About Eve  Drama    138.0           8.0
# 901                            Rebecca  Drama    130.0           7.7
# 904                         Spellbound  Drama    111.0           7.3
# 915                              Laura  Drama     88.0           7.6
# ...

# %%
type(generes)
# Out:
# pandas.core.frame.DataFrame

# %%
movies = pd.concat([movies, generes], axis=1, sort=False)

# %%
movies = movies.drop('genres',axis=1)

# %% [markdown]
# movies

# %%
movies
# Out:
#                                   title  runtime  vote_average  vote_count  \
# 0                             Toy Story     81.0           7.7      5415.0
# 1                               Jumanji    104.0           6.9      2413.0
# 2                      Grumpier Old Men    101.0           6.5        92.0
# 3                     Waiting to Exhale    127.0           6.1        34.0
# 4           Father of the Bride Part II    106.0           5.7       173.0
# 5                                  Heat    170.0           7.7      1886.0
# 6                               Sabrina    127.0           6.2       141.0
# 7                          Tom and Huck     97.0           5.4        45.0
# 8                          Sudden Death    106.0           5.5       174.0
# 9                             GoldenEye    130.0           6.6      1194.0
# 10               The American President    106.0           6.5       199.0
# ...

# %%
def is_genere():
    genere_list = ["genere_{}".format(x) for x in range(0,8)]
    for i in genere_list:
        if x[i] == g:
            return True

# %%
n_movies.apply(is_genere)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-6d9d5de685f0> in <module>()
# ----> 1 n_movies.apply(is_genere)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/apply.pyc in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/apply.pyc in get_result(self)
#     140             return self.apply_raw()
#     141
# ...

# %%
# Out:
# ['genere_0',
#  'genere_1',
#  'genere_2',
#  'genere_3',
#  'genere_4',
#  'genere_5',
#  'genere_6',
#  'genere_7']

# %%
# Out:
# genere_0
# genere_1
# genere_2
# genere_3
# genere_4
# genere_5
# genere_6
# genere_7

# %%
n_movies['genere_0']
# Out:
# 0              Animation
# 1              Adventure
# 2                Romance
# 3                 Comedy
# 4                 Comedy
# 5                 Action
# 6                 Comedy
# 7                 Action
# 8                 Action
# 9              Adventure
# 10                Comedy
# 11                Comedy
# 12                Family
# 13               History
# 14                Action
# 15                 Drama
# 16                 Drama
# 17                 Crime
# 18                 Crime
# 19                Action
# 20                Comedy
# 21                 Drama
# 22                Action
# 23                 Drama
# 24                 Drama
# 25                 Drama
# 26                Comedy
# 27                 Drama
# 28               Fantasy
# 29                 Drama
#               ...
# 45436             Action
# 45437             Family
# 45438              Drama
# 45439              Drama
# 45440              Drama
# 45441             Comedy
# ...

# %%
n_movies.apply(is_genere)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-6d9d5de685f0> in <module>()
# ----> 1 n_movies.apply(is_genere)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/apply.pyc in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/apply.pyc in get_result(self)
#     140             return self.apply_raw()
#     141
# ...

# %%
movies = movies[(movies['release_year'] >= low_year) & (movies['release_year'] <= high_year)]

# %%
movies
# Out:
#                                             title  \
# 587               Snow White and the Seven Dwarfs
# 589                                     Pinocchio
# 728                                 Force of Evil
# 731                       The Man from Down Under
# 737                                           Kim
# 833                            Crows and Sparrows
# 867                                      Liebelei
# 870                       For Whom the Bell Tolls
# 871                        The Philadelphia Story
# 878                         It Happened One Night
# 879                                      Gaslight
# 880                              The Gay Divorcee
# 885                                    Casablanca
# 886                            The Maltese Falcon
# 890                           The Little Princess
# 891                          Meet Me in St. Louis
# 892                              The Wizard of Oz
# 893                            Gone with the Wind
# ...
