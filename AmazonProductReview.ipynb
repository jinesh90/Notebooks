# %%
import graphlab

# %%
product = graphlab.SFrame('/home/jinesh/Desktop/amazon.csv')
# Out:
# Unable to parse line "AVpfl8cLLJeJML43AE3S,"Amazon Fire Tv,,,"
# Unable to parse line "Amazon Fire Tv,,,","B00L9EPT8O,B01E6AO69U",Amazon,"Stereos,Remote Controls,Amazon Echo,Audio Docks & Mini Speakers,Amazon Echo Accessories,Kitchen & Dining Features,Speaker Systems,Electronics,TVs Entertainment,Clearance,Smart Hubs & Wireless Routers,Featu..."
# Unable to parse line "AVpfl8cLLJeJML43AE3S,"Amazon Fire Tv,,,"
# Unable to parse line "Amazon Fire Tv,,,","B00L9EPT8O,B01E6AO69U",Amazon,"Stereos,Remote Controls,Amazon Echo,Audio Docks & Mini Speakers,Amazon Echo Accessories,Kitchen & Dining Features,Speaker Systems,Electronics,TVs Entertainment,Clearance,Smart Hubs & Wireless Routers,Featu..."
# Unable to parse line "AVpfl8cLLJeJML43AE3S,"Amazon Fire Tv,,,"
# ...

# %%
product
# Out:
# Columns:
# 	id	str
# 	name	str
# 	asins	str
# 	brand	str
# 	categories	str
# 	keys	str
# 	manufacturer	str
# 	reviews.date	str
# 	reviews.dateAdded	str
# 	reviews.dateSeen	str
# 	reviews.didPurchase	str
# 	reviews.doRecommend	str
# 	reviews.id	str
# 	reviews.numHelpful	int
# 	reviews.rating	int
# 	reviews.sourceURLs	str
# 	reviews.text	str
# 	reviews.title	str
# 	reviews.userCity	str
# 	reviews.userProvince	str
# 	reviews.username	str
#
# Rows: 27899
#
# Data:
# +----------------------+-------------------------------+------------+--------+
# |          id          |              name             |   asins    | brand  |
# +----------------------+-------------------------------+------------+--------+
# | AVqkIhwDv8e3D1O-lebb | All-New Fire HD 8 Tablet, ... | B01AHB9CN2 | Amazon |
# | AVqkIhwDv8e3D1O-lebb | All-New Fire HD 8 Tablet, ... | B01AHB9CN2 | Amazon |
# | AVqkIhwDv8e3D1O-lebb | All-New Fire HD 8 Tablet, ... | B01AHB9CN2 | Amazon |
# ...

# %%
product.rename({'reviews.text':'text'})
# Out:
# Columns:
# 	id	str
# 	name	str
# 	asins	str
# 	brand	str
# 	categories	str
# 	keys	str
# 	manufacturer	str
# 	reviews.date	str
# 	reviews.dateAdded	str
# 	reviews.dateSeen	str
# 	reviews.didPurchase	str
# 	reviews.doRecommend	str
# 	reviews.id	str
# 	reviews.numHelpful	int
# 	reviews.rating	int
# 	reviews.sourceURLs	str
# 	text	str
# 	title	str
# 	reviews.userCity	str
# 	reviews.userProvince	str
# 	reviews.username	str
#
# Rows: 27899
#
# Data:
# +----------------------+-------------------------------+------------+--------+
# |          id          |              name             |   asins    | brand  |
# +----------------------+-------------------------------+------------+--------+
# | AVqkIhwDv8e3D1O-lebb | All-New Fire HD 8 Tablet, ... | B01AHB9CN2 | Amazon |
# | AVqkIhwDv8e3D1O-lebb | All-New Fire HD 8 Tablet, ... | B01AHB9CN2 | Amazon |
# | AVqkIhwDv8e3D1O-lebb | All-New Fire HD 8 Tablet, ... | B01AHB9CN2 | Amazon |
# ...

# %%
product.show(view='Categorical')
# Out:
# WARNING:root:View param Categorical is not recognized. You may want to use "Summary", "Plots", "Table" or a specific plot type such as "Scatter Plot". I am showing you the Summary view for now.
# Canvas is accessible via web browser at the URL: http://localhost:41139/index.html
# Opening Canvas in default web browser.
# WARNING:root:View param Categorical is not recognized. You may want to use "Summary", "Plots", "Table" or a specific plot type such as "Scatter Plot". I am showing you the Summary view for now.
# WARNING:root:View param Categorical is not recognized. You may want to use "Summary", "Plots", "Table" or a specific plot type such as "Scatter Plot". I am showing you the Summary view for now.
# WARNING:root:View param Categorical is not recognized. You may want to use "Summary", "Plots", "Table" or a specific plot type such as "Scatter Plot". I am showing you the Summary view for now.
# ...

# %%
product['word_count']=graphlab.text_analytics.count_words(product['text'])

# %%
product
# Out:
# Columns:
# 	recommend	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
#
# Rows: 27899
#
# Data:
# +-----------+--------+-------------------------------+
# | recommend | rating |              text             |
# +-----------+--------+-------------------------------+
# |    TRUE   |   5    | This product so far has no... |
# |    TRUE   |   5    | great for beginner or expe... |
# |    TRUE   |   5    | Inexpensive tablet for him... |
# |    TRUE   |   4    | I've had my Fire HD 8 two ... |
# |    TRUE   |   5    | I bought this for my grand... |
# |    TRUE   |   5    | This amazon fire 8 inch ta... |
# |    TRUE   |   4    | Great for e-reading on the... |
# |    TRUE   |   5    | I gave this as a Christmas... |
# |    TRUE   |   5    | Great as a device to read ... |
# |    TRUE   |   5    | I love ordering books and ... |
# +-----------+--------+-------------------------------+
# +-------------------------------+-------------------------------+
# ...

# %%
product.remove_columns(['id','asins','brand','categories','keys','manufacturer','reviews.date','reviews.dateAdded'
                       ,'reviews.dateSeen','reviews.didPurchase','reviews.id','reviews.doRecommend','reviews.numHelpful',
                       'reviews.sourceURLs','reviews.userCity','reviews.userProvince','reviews.username'])
# Out:
# Columns:
# 	name	str
# 	reviews.rating	int
# 	reviews.text	str
# 	reviews.title	str
#
# Rows: 27899
#
# Data:
# +-------------------------------+----------------+
# |              name             | reviews.rating |
# +-------------------------------+----------------+
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       4        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       4        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# | All-New Fire HD 8 Tablet, ... |       5        |
# +-------------------------------+----------------+
# +-------------------------------+-------------------------------+
# |          reviews.text         |         reviews.title         |
# ...

# %%
product.rename({'reviews.rating':'rating','reviews.text':'text','reviews.title':'title'})
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
#
# Rows: 27899
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
product['word_count']=graphlab.text_analytics.count_words(product['text'])

# %%
product.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:41139/index.html
# Opening Canvas in default web browser.

# %%
product['name']
# Out:
# dtype: str
# Rows: 27899
# ...

# %%
fire_tablet = product[product['name']=='All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta']

# %%
fire_tablet
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
fire_tablet.materialize()

# %%
fire_tablet
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
#
# Rows: 2814
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
training_data,test_data = product.random_split(.8,seed=0)

# %%
sentiment_model = graphlab.logistic_classifier.create(training_data,
                                                     target='rating',features=['word_count'],
                                                     validation_set=test_data,
                                                     max_iterations=100)
# Out:
# [ERROR] graphlab.toolkits._main: Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ERROR:graphlab.toolkits._main:Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-41-082250576fe7> in <module>()
#       2                                                      target='rating',features=['word_count'],
#       3                                                      validation_set=test_data,
# ----> 4                                                      max_iterations=100)
#
# ...

# %%
product.dropna()
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
sentiment_model = graphlab.logistic_classifier.create(training_data,
                                                     target='rating',features=['word_count'],
                                                     validation_set=test_data,
                                                     max_iterations=100)
# Out:
# [ERROR] graphlab.toolkits._main: Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ERROR:graphlab.toolkits._main:Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-43-082250576fe7> in <module>()
#       2                                                      target='rating',features=['word_count'],
#       3                                                      validation_set=test_data,
# ----> 4                                                      max_iterations=100)
#
# ...

# %%
product
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
#
# Rows: 27899
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
product['sentiment'] = product['rating'] >= 3

# %%
product
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
# 	sentiment	int
#
# Rows: 27899
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
product.dropna()
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
# 	sentiment	int
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
training_data,test_data = product.random_split(.8,seed=0)

# %%
product.dropna()
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
# 	sentiment	int
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
sentiment_model = graphlab.logistic_classifier.create(training_data,
                                                     target='sentiment',features=['word_count'],
                                                     validation_set=test_data)
# Out:
# [ERROR] graphlab.toolkits._main: Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ERROR:graphlab.toolkits._main:Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-75-d2e7637dad78> in <module>()
#       1 sentiment_model = graphlab.logistic_classifier.create(training_data,
#       2                                                      target='sentiment',features=['word_count'],
# ----> 3                                                      validation_set=test_data)
#
# ...

# %%
product
# Out:
# Columns:
# 	name	str
# 	rating	int
# 	text	str
# 	title	str
# 	word_count	dict
# 	sentiment	int
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------+-------------------------------+
# |              name             | rating |              text             |
# +-------------------------------+--------+-------------------------------+
# | All-New Fire HD 8 Tablet, ... |   5    | This product so far has no... |
# | All-New Fire HD 8 Tablet, ... |   5    | great for beginner or expe... |
# | All-New Fire HD 8 Tablet, ... |   5    | Inexpensive tablet for him... |
# | All-New Fire HD 8 Tablet, ... |   4    | I've had my Fire HD 8 two ... |
# | All-New Fire HD 8 Tablet, ... |   5    | I bought this for my grand... |
# | All-New Fire HD 8 Tablet, ... |   5    | This amazon fire 8 inch ta... |
# | All-New Fire HD 8 Tablet, ... |   4    | Great for e-reading on the... |
# | All-New Fire HD 8 Tablet, ... |   5    | I gave this as a Christmas... |
# ...

# %%
product.materialize()

# %%
product=product.materialize()

# %%
product = product.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-fa389a805336> in <module>()
# ----> 1 product = product.dropna()
#
# AttributeError: 'NoneType' object has no attribute 'dropna'
